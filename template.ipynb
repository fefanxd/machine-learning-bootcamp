# %% [markdown]
# <a href="https://colab.research.google.com/github/fefanxd/machine-learning-bootcamp/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Dzień dobry")
# Out:
# Dzień dobry
